# %%
import sys
import numpy as np
import os 
import line_profiler
print(os.getcwd())
os.chdir("/home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/")
sys.path.append("./dynamic_model/")
# sys.path.append("./MISC/exploratory_analysis/")
# sys.path.append("./MISC//")
from simulation_and_plotting.simulation import Simulation
from agents.sounds import EchoSound, DirectSound
from agents.bats import Bat
# from simulation_and_plotting.single_bat_plotter import visualize
from supporting_files.utilities import load_parameters
from supporting_files.snr_implementation import given_sound_objects_return_detected_sounds, is_signal_heard, get_temporal_masking_function_based_on_sound, generate_sound_profile
from supporting_files.vectors import Vector
# %load_ext line_profiler

OUTPUT_DIR = r"./dynamic_model/profiling/dump_files/"
PARAMETER_FILE_DIR = r"./dynamic_model/paramsets/common_parameters.json"
PARAMETER_DF = load_parameters(PARAMETER_FILE_DIR)
sim = Simulation(PARAMETER_DF, OUTPUT_DIR)
# Out:
# /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/profiling

# %%
OUTPUT_DIR = r"./dynamic_model/profiling/dump_files/"
PARAMETER_FILE_DIR = r"./dynamic_model/paramsets/common_parameters.json"
PARAMETER_DF = load_parameters(PARAMETER_FILE_DIR)
sim = Simulation(PARAMETER_DF, OUTPUT_DIR)

# %%
# %lprun -f Simulation.run sim.run()
# Out:
# 0.003
# 0.052
# 0.157
# 0.263
# 0.368
# 0.417
# 0.464
# 0.573
# 0.621
# 0.667
# 0.71
# 0.762
# 0.817
# 0.868
# 0.912
# 0.964
# total_time_taken_to_store_info: 0:00:32.341997
# average_time_per_loop 0:00:00.032342
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 33.3065 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/simulation_and_plotting/simulation.py
# Function: Simulation.run at line 64
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     64                                               def run(self):
#     65                                                   """Runs one instance of the simulation.
#     66                                                   After parsing the parameter file, it runs one instance of the simulation
#     67                                                   for those sets of parameters.
#     68                                                   """
#     69         2     900865.0 450432.5      0.0          with open(self.dir_to_store + "bats_initial.pkl", "wb") as f:
#     70         1     339618.0 339618.0      0.0              pickle.dump(self.bats, f)
#     71         2      57893.0  28946.5      0.0          with open(self.dir_to_store + "obstacles_initial.pkl", "wb") as f:
#     72         1     151967.0 151967.0      0.0              pickle.dump(self.obstacles, f)
#     73
#     74         2       1345.0    672.5      0.0          num_steps = int(
#     75         1       1421.0   1421.0      0.0              self.parameters_df["SIM_DURATION"][0] / self.parameters_df["TIME_STEP"][0]
#     76                                                   )
#     77         1       4060.0   4060.0      0.0          start_timing = datetime.now()
#     78         1        345.0    345.0      0.0          list_time_taken_for_each_loop = []
#     79         1        249.0    249.0      0.0          save_time_of_last_iter = start_timing
#     80      1001     599335.0    598.7      0.0          for step in range(num_steps):
#     81                                                       # print(self.obstacles[0].position.x)
#     82      1000     528806.0    528.8      0.0              self.time_elapsed = step * self.parameters_df["TIME_STEP"][0]
#     83
#     84    146259   31655237.0    216.4      0.1              for sound in self.sound_objects:
#     85    145259  447215513.0   3078.7      1.3                  sound.update(self.time_elapsed)
#     86
#     87     11000    4510623.0    410.1      0.0              for bat in self.bats:
#     88     10000     2.93e+10 2.93e+06     87.9                  bat.update(self.time_elapsed, self.sound_objects)
#     89
#     90      1000 1064677393.0 1.06e+06      3.2              self.handle_reflections(self.time_elapsed)
#     91
#     92      2000     876540.0    438.3      0.0              self.history.append(
#     93      1000     811759.0    811.8      0.0                  {
#     94      2000   10876286.0   5438.1      0.0                      "time": np.round(
#     95      1000     269624.0    269.6      0.0                          self.time_elapsed, self.rounding_based_on_time_step
#     96                                                               ),
#     97      1000    1391518.0   1391.5      0.0                      "bat_ipi_counters": [len(bat.emit_times) for bat in self.bats],
#     98     11000    2404432.0    218.6      0.0                      "bat_positions": [
#     99     11000    3838857.0    349.0      0.0                          (bat.position.x, bat.position.y) for bat in self.bats
#    100                                                               ],
#    101     11000    2684417.0    244.0      0.0                      "bat_directions": [
#    102     10000   43610093.0   4361.0      0.1                          (bat.direction.normalize().x, bat.direction.normalize().y)
#    103     11000    2401600.0    218.3      0.0                          for bat in self.bats
#    104                                                               ],
#    105     11000    3145666.0    286.0      0.0                      "bat_detections": [
#    106     10000  427010857.0  42701.1      1.3                          bat.get_detections_at_time(self.time_elapsed)
#    107     11000    2431504.0    221.0      0.0                          for bat in self.bats
#    108                                                               ],
#    109    153539   35531271.0    231.4      0.1                      "sound_objects": [
#    110    152539  529356000.0   3470.3      1.6                          self.serialize_sound(s)
#    111    153539   32147169.0    209.4      0.1                          for s in self.sound_objects
#    112    152539   33154321.0    217.3      0.1                          if s.active
#    113    145893   39970139.0    274.0      0.1                          and s.current_spl > self.parameters_df["HEARING_THRESHOLD"][0]
#    114                                                               ],
#    115      1000     463107.0    463.1      0.0                      "sound_objects_count": len(self.sound_objects),
#    116     11000    2707561.0    246.1      0.0                      "next_dir_angle": [
#    117     10000   22275756.0   2227.6      0.1                          bat.next_direction.angle_between(Vector(1, 0))
#    118     11000    2402368.0    218.4      0.0                          for bat in self.bats
#    119                                                               ],
#    120     11000    2502161.0    227.5      0.0                      "current_dir_angle": [
#    121     11000   17348535.0   1577.1      0.1                          bat.direction.angle_between(Vector(1, 0)) for bat in self.bats
#    122                                                               ],
#    123     11000    2210295.0    200.9      0.0                      "bat_response_vector": [
#    124     11000    2899317.0    263.6      0.0                          bat.responding_to_direction for bat in self.bats
#    125                                                               ],
#    126      1000     759344.0    759.3      0.0                      "response_type": [bat.response_type for bat in self.bats],
#    127      1000     831360.0    831.4      0.0                      "bat_ipi_matrix": [bat.ipi_matrix for bat in self.bats],
#    128     11000    2233092.0    203.0      0.0                      "bat_sum_matrix": [
#    129     11000    2604498.0    236.8      0.0                          bat.memory_window_sum_matrix for bat in self.bats
#    130                                                               ],
#    131                                                           }
#    132                                                       )
#    133                                                       # self.history_manager.add_frame(self.time_elapsed, self.bats)
#    134
#    135    153539   36093803.0    235.1      0.1              self.sound_objects = [
#    136    153539   37728599.0    245.7      0.1                  s for s in self.sound_objects if s.active and s.current_spl > 20
#    137                                                       ]
#    138
#    139      1000    2970455.0   2970.5      0.0              current_loop_time = datetime.now()
#    140      2000     668634.0    334.3      0.0              list_time_taken_for_each_loop.append(
#    141      1000     684852.0    684.9      0.0                  current_loop_time - save_time_of_last_iter
#    142                                                       )
#    143
#    144      1000     406035.0    406.0      0.0              save_time_of_last_iter = current_loop_time
#    145      1000    3076288.0   3076.3      0.0              self.handle_data_storage_for_plotting(self.time_elapsed, False)
#    146      1000    2076538.0   2076.5      0.0              self.handle_data_storage_for_plotting_pickle(self.time_elapsed, False)
#    147         1   11048065.0  1.1e+07      0.0          self.handle_data_storage_for_plotting(self.time_elapsed, True)
#    148         1 1140785877.0 1.14e+09      3.4          self.handle_data_storage_for_plotting_pickle(self.time_elapsed, True)
#    149         1     109134.0 109134.0      0.0          print(f"total_time_taken_to_store_info: {save_time_of_last_iter-start_timing}")
#    150         1     430982.0 430982.0      0.0          print(f"average_time_per_loop {np.mean(list_time_taken_for_each_loop)}")
#    151         1      30685.0  30685.0      0.0          print("DATA SAVED")

# %%
# %lprun -f EchoSound.update sim.run()
# Out:
# 0.058
# 0.155
# 0.265
# 0.366
# 0.472
# 0.578
# 0.688
# 0.783
# 0.893
# 0.987
# total_time_taken_to_store_info: 0:01:34.480023
# average_time_per_loop 0:00:00.094480
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 24.3074 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/sounds.py
# Function: EchoSound.update at line 55
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     55                                               def update(self, current_time):
#     56                                                   """Function to propagate sound with time.
#     57                                                   This function updates the radius of the sound disk with time.
#     58                                                   Also, ensures sounds outside the arena are "disabled" and no longer tracked.
#     59
#     60                                                   Args:
#     61                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#     62                                                   """
#     63  11192048 2729303968.0    243.9     11.2          elapsed = current_time - self.creation_time
#     64  11192048 3067785106.0    274.1     12.6          self.current_radius = self.speed * elapsed
#     65
#     66                                                   # Calculate spl with distance and air absorption
#     67
#     68  11192048 2758986444.0    246.5     11.4          if self.current_radius > 0:
#     69   2501080  810462644.0    324.0      3.3              distance_effect = 20 * math.log10(self.current_radius / 1)
#     70   2501080  560768765.0    224.2      2.3              self.current_spl = (
#     71   7503240 1841928690.0    245.5      7.6                  self.initial_spl
#     72   2501080  520999017.0    208.3      2.1                  - distance_effect
#     73   2501080  679323298.0    271.6      2.8                  - (self.parameters_df["AIR_ABSORPTION"][0] * self.current_radius)
#     74                                                       )
#     75
#     76  11192048     1.13e+10   1009.4     46.5          if self.check_if_sound_outside_arena():
#     77    105882   41100387.0    388.2      0.2              self.active = False

# %%
# %lprun -f EchoSound.check_if_sound_outside_arena sim.run()
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('lprun', '-f EchoSound.check_if_sound_outside_arena sim.run()')
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/line_profiler/ipython_extension.py:130, in LineProfilerMagics.lprun(self, parameter_s)
#     128 try:
#     129     try:
# --> 130         profile.runctx(arg_str, global_ns, local_ns)
#     131         message = ""
#     132     except SystemExit:
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/line_profiler/profiler_mixin.py:496, in ByCountProfilerMixin.runctx(self, cmd, globals, locals)
#     494 self.enable_by_count()
#     495 try:
# --> 496     exec(cmd, globals, locals)
#     497 finally:
#     498     self.disable_by_count()
#
# File <string>:1
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/simulation_and_plotting/simulation.py:88, in Simulation.run(self)
#      85     sound.update(self.time_elapsed)
#      87 for bat in self.bats:
# ---> 88     bat.update(self.time_elapsed, self.sound_objects)
#      90 self.handle_reflections(self.time_elapsed)
#      92 self.history.append(
#      93     {
#      94         "time": np.round(
#    (...)    131     }
#     132 )
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py:133, in Bat.update(self, current_time, sound_objects)
#     129 # if current_time < 0.5:
#     130 #     print(self.ipi_matrix)
#     131 # print(self.ipi_matrix_timeseries)
#     132 if not self.kill_movement:
# --> 133     self.update_directon(current_time, sound_objects)
#     134     self.cleanup_sounds(current_time)
#     135     self.detect_sounds(current_time, sound_objects)
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py:424, in Bat.update_directon(self, current_time, sound_objects)
#     419 # self.reaction_time += self.parameters_df["TIME_STEP"][0]
#     420 direction_change_time_interval = self.parameters_df[
#     421     "TIME_DELAY_FOR_DIRECTION_CHANGE"
#     422 ][0]
#     423 self.detections_for_directon_change.extend(
# --> 424     self.given_sound_objects_return_sounds_at_bat_position(
#     425         current_time, sound_objects, detect_self_call=False
#     426     )
#     427 )
#     429 if (
#     430     self.time_since_directon_change >= direction_change_time_interval
#     431     and len(self.detections_for_directon_change) != 0
#     432 ):
#     433     # print(len(self.detections_for_directon_change))
#     434     if self.implement_snr:
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py:252, in Bat.given_sound_objects_return_sounds_at_bat_position(self, current_time, sound_objects, detect_self_call)
#     250 array_of_sound_detections = []
#     251 for sound in sound_objects:
# --> 252     sound.update(current_time)
#     254     is_sound_active = sound.active
#     255     is_sound_self_call = (
#     256         sound.emitter_id == self.id
#     257         and isinstance(sound, DirectSound)
#     258         and not detect_self_call
#     259     )
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/sounds.py:77, in EchoSound.update(self, current_time)
#      70     distance_effect = 20 * math.log10(self.current_radius / 1)
#      71     self.current_spl = (
#      72         self.initial_spl
#      73         - distance_effect
#      74         - (self.parameters_df["AIR_ABSORPTION"][0] * self.current_radius)
#      75     )
# ---> 77 if self.check_if_sound_outside_arena():
#      78     self.active = False
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/sounds.py:133, in EchoSound.check_if_sound_outside_arena(self)
#     126 def check_if_sound_outside_arena(self):
#     127     """Checks if sound is outside the bounds of the arena.
#     128     Sound obejct is no longer tracked if its outside the arena.
#     129
#     130     Returns:
#     131         Bool: True if sound is outside the bounds of the arena, else False.
#     132     """
# --> 133     if (self.current_radius) > np.max(self.arena_LENGTH, self.arena_width):
#     134         return True
#     135     else:
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3163, in max(a, axis, out, keepdims, initial, where)
#    3051 @array_function_dispatch(_max_dispatcher)
#    3052 @set_module('numpy')
#    3053 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    3054          where=np._NoValue):
#    3055     """
#    3056     Return the maximum of an array or maximum along an axis.
#    3057
#    (...)   3161     5
#    3162     """
# -> 3163     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    3164                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# AxisError: axis 7 is out of bounds for array of dimension 0

# %%
# %lprun -f Simulation.handle_reflections sim.run()
# Out:
# 0.009
# 0.065
# 0.16
# 0.268
# 0.369
# 0.475
# 0.581
# 0.681
# 0.784
# 0.883
# 0.977
# total_time_taken_to_store_info: 0:00:23.558804
# average_time_per_loop 0:00:00.023559
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 1.19397 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/simulation_and_plotting/simulation.py
# Function: Simulation.handle_reflections at line 217
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    217                                               def handle_reflections(self, current_time):
#    218                                                   """Generates reflections of the sound objects.
#    219                                                   Soud objects can reflect off of obstacles and bats
#    220                                                   to generate EchoSound s.
#    221
#    222                                                   Args:
#    223                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    224                                                   """
#    225      1000     569836.0    569.8      0.0          new_echoes = []
#    226
#    227    141501   29935973.0    211.6      2.5          for sound in self.sound_objects:
#    228    140501   33220737.0    236.4      2.8              if not sound.active or not isinstance(sound, DirectSound):
#    229    138154   27144066.0    196.5      2.3                  continue
#    230
#    231      2347     570976.0    243.3      0.0              reflection_point = None
#    232      2347     507930.0    216.4      0.0              normal = None
#    233      2347     461997.0    196.8      0.0              obstacle_id = None
#    234
#    235      2347    1400677.0    596.8      0.1              reflection_point_arr, normal_arr, obstacle_id_arr = [], [], []
#    236
#    237                                                       # Check walls
#    238      2347     934299.0    398.1      0.1              wall_points_to_check = [
#    239      2347    2908550.0   1239.3      0.2                  Vector(0, sound.origin.y),
#    240      2347    2654656.0   1131.1      0.2                  Vector(sound.origin.x, 0),
#    241      2347    2523754.0   1075.3      0.2                  Vector(self.parameters_df["ARENA_WIDTH"][0], sound.origin.y),
#    242      2347    2364838.0   1007.6      0.2                  Vector(sound.origin.x, self.parameters_df["ARENA_LENGTH"][0]),
#    243                                                       ]
#    244      2347     974892.0    415.4      0.1              wall_ids = ["left", "down", "right", "up"]
#    245     11735    4429725.0    377.5      0.4              for i, wall_point in enumerate(wall_points_to_check):
#    246                                                           if (
#    247      9388   32548448.0   3467.0      2.7                      sound.contains_point(wall_point)
#    248       889     629543.0    708.1      0.1                      and f"wall_{wall_ids[i]}" not in sound.reflected_obstacles
#    249                                                           ):
#    250       447    1690642.0   3782.2      0.1                      normal = (sound.origin - wall_point).normalize()
#    251       447     111026.0    248.4      0.0                      reflection_point = wall_point
#    252       447     137894.0    308.5      0.0                      obstacle_id = f"wall_{wall_ids[i]}"
#    253
#    254       447     128713.0    287.9      0.0                      normal_arr.append(normal)
#    255       447     101300.0    226.6      0.0                      reflection_point_arr.append(reflection_point)
#    256       447     106264.0    237.7      0.0                      obstacle_id_arr.append(obstacle_id)
#    257
#    258                                                       # Check obstacles
#    259    124391   32712406.0    263.0      2.7              for obstacle in self.obstacles:
#    260                                                           if (
#    261    122044  373801671.0   3062.8     31.3                      sound.contains_point(obstacle.position)
#    262     10825    5510215.0    509.0      0.5                      and f"wall_{obstacle.id}" not in sound.reflected_obstacles
#    263                                                           ):
#    264     10825   42731594.0   3947.5      3.6                      normal = obstacle.get_reflection_normal(sound.origin)
#    265     10825   29135105.0   2691.5      2.4                      reflection_point = obstacle.position + normal * obstacle.radius
#    266     10825    4230685.0    390.8      0.4                      obstacle_id = f"obstacle_{obstacle.id}"
#    267
#    268     10825    3090757.0    285.5      0.3                      normal_arr.append(normal)
#    269     10825    2548158.0    235.4      0.2                      reflection_point_arr.append(reflection_point)
#    270     10825    2730739.0    252.3      0.2                      obstacle_id_arr.append(obstacle_id)
#    271
#    272                                                       # Check other bats
#    273     25817    7362290.0    285.2      0.6              for bat in self.bats:
#    274                                                           if (
#    275     23470   74160810.0   3159.8      6.2                      sound.contains_point(bat.position)
#    276      2345     780523.0    332.8      0.1                      and sound.emitter_id != bat.id
#    277      2009    1069606.0    532.4      0.1                      and f"bat_{bat.id}" not in sound.reflected_obstacles
#    278      1005     320034.0    318.4      0.0                      and bat.is_bat_reflective_to_sound
#    279                                                           ):
#    280      1005    3598894.0   3581.0      0.3                      normal = (sound.origin - bat.position).normalize()
#    281      1005    2717000.0   2703.5      0.2                      reflection_point = bat.position + normal * bat.radius
#    282      1005     390102.0    388.2      0.0                      obstacle_id = f"bat_{bat.id}"
#    283
#    284      1005     293956.0    292.5      0.0                      normal_arr.append(normal)
#    285      1005     246920.0    245.7      0.0                      reflection_point_arr.append(reflection_point)
#    286      1005     272635.0    271.3      0.0                      obstacle_id_arr.append(obstacle_id)
#    287
#    288     14624    4624267.0    316.2      0.4              for i, reflection_point in enumerate(reflection_point_arr):
#    289     12277    3143348.0    256.0      0.3                  normal = normal_arr[i]
#    290     12277    2834739.0    230.9      0.2                  obstacle_id = obstacle_id_arr[i]
#    291     12277    3882029.0    316.2      0.3                  if obstacle_id not in sound.reflected_obstacles:
#    292     13976   26687927.0   1909.6      2.2                      time_of_creation = creation_time_calculation(
#    293      6988    1581808.0    226.4      0.1                          sound, reflection_point
#    294                                                               )
#    295     13976  372145787.0  26627.5     31.2                      echo = sound.create_echo(
#    296      6988    1724937.0    246.8      0.1                          reflection_point, time_of_creation, normal, obstacle_id
#    297                                                               )
#    298
#    299      6988    2017015.0    288.6      0.2                      if echo:
#    300                                                                   # Mark this obstacle as reflected for the original sound
#    301      6988   27536089.0   3940.5      2.3                          echo.update(current_time)
#    302      6988    2544058.0    364.1      0.2                          sound.reflected_obstacles.add(obstacle_id)
#    303                                                                   # Copy reflected obstacles to the echo
#    304      6988    7139138.0   1021.6      0.6                          echo.reflected_obstacles.update(sound.reflected_obstacles)
#    305      6988    1994977.0    285.5      0.2                          new_echoes.append(echo)
#    306
#    307      1000    2348425.0   2348.4      0.2          self.sound_objects.extend(new_echoes)

# %%
# %lprun -f Bat.update sim.run()
# Out:
# 0.075
# 0.118
# 0.167
# 0.26
# 0.319
# 0.367
# 0.468
# 0.571
# 0.617
# 0.723
# 0.831
# 0.934
# total_time_taken_to_store_info: 0:01:03.516642
# average_time_per_loop 0:00:00.063517
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 56.2547 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py
# Function: Bat.update at line 108
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    108                                               def update(self, current_time, sound_objects):
#    109                                                   """Function to update bats with time.
#    110                                                   This function handles movement update of bat each time step.
#    111                                                   Also takes care of sound emission, detection of active sounds by the bats.
#    112                                                   Bat detections over time is also cleared and stored locally.
#    113
#    114                                                   Args:
#    115                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    116                                                       sound_objects (EchoSound): direct and echo sounds that are currently active.
#    117                                                   """
#    118
#    119     10000  116407794.0  11640.8      0.2          current_time = np.round(current_time, self.rounding_based_on_time_step)
#    120     10000    3840133.0    384.0      0.0          if not self.kill_movement:
#    121     10000   77002930.0   7700.3      0.1              self.update_movement()
#    122     20000    6895205.0    344.8      0.0              self.position_history.append(
#    123     10000    3055344.0    305.5      0.0                  (current_time, (self.position.x, self.position.y))
#    124                                                       )
#    125
#    126     10000   55833939.0   5583.4      0.1          self.emit_sounds(current_time, sound_objects)
#    127     10000    2913491.0    291.3      0.0          if self.id == 0 and self.time_since_directon_change == 0:
#    128        12    1296275.0 108022.9      0.0              print(current_time)
#    129                                                   # if current_time < 0.5:
#    130                                                   #     print(self.ipi_matrix)
#    131                                                   # print(self.ipi_matrix_timeseries)
#    132     10000    2556775.0    255.7      0.0          if not self.kill_movement:
#    133     10000     2.83e+10 2.83e+06     50.3              self.update_directon(current_time, sound_objects)
#    134     10000  547900881.0  54790.1      1.0              self.cleanup_sounds(current_time)
#    135     10000     2.71e+10 2.71e+06     48.3              self.detect_sounds(current_time, sound_objects)
#    136                                                       # self.next_direction = self.direction

# %%
# %lprun -f Bat.detect_sounds sim.run()
# Out:
# 0.04
# 0.145
# 0.239
# 0.331
# 0.425
# 0.528
# 0.623
# 0.719
# 0.826
# 0.934
# total_time_taken_to_store_info: 0:01:01.460590
# average_time_per_loop 0:00:00.061461
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 26.9699 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py
# Function: Bat.detect_sounds at line 293
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    293                                               def detect_sounds(self, current_time, sound_objects):
#    294                                                   """Detects sound that are audible to the Bat
#    295                                                   Checks if a bat can hear a sound based on dbSpl of sound
#    296                                                   and position of bat.
#    297
#    298                                                   Args:
#    299                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    300                                                       sound_objects (list): _description_
#    301                                                   """
#    302     20000   13119677.0    656.0      0.0          self.received_sounds.extend(
#    303     20000     2.69e+10 1.35e+06     99.9              self.given_sound_objects_return_sounds_at_bat_position(
#    304     10000    2935702.0    293.6      0.0                  current_time, sound_objects, detect_self_call=True
#    305                                                       )
#    306                                                   )
#    307     10000    5949727.0    595.0      0.0          self.ipi_matrix_timeseries.append(self.ipi_matrix)
#    308     20000    9934472.0    496.7      0.0          self.memory_window_to_store_grids_timeseries.append(
#    309     10000    3256816.0    325.7      0.0              self.memory_window_to_store_grids
#    310                                                   )

# %%
# %lprun -f Bat.given_sound_objects_return_sounds_at_bat_position sim.run()
# Out:
# 0.081
# 0.173
# 0.273
# 0.383
# 0.493
# 0.589
# 0.68
# 0.773
# 0.868
# 0.965
# total_time_taken_to_store_info: 0:00:46.572065
# average_time_per_loop 0:00:00.046572
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 33.3313 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py
# Function: Bat.given_sound_objects_return_sounds_at_bat_position at line 237
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    237                                               def given_sound_objects_return_sounds_at_bat_position(
#    238                                                   self, current_time, sound_objects, detect_self_call
#    239                                               ):
#    240                                                   """given sounds generate list of sounds that a bat can hear
#    241
#    242                                                   Args:
#    243                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    244                                                       sound_objects (list): List containing all active sounds in the simulation
#    245                                                       detect_self_call (Bool): If true, add self call to detected, else, skip self call.
#    246
#    247                                                   Returns:
#    248                                                       list: sound detections given time.
#    249                                                   """
#    250     20000    6067018.0    303.4      0.0          array_of_sound_detections = []
#    251   6322062 1484552863.0    234.8      4.5          for sound in sound_objects:
#    252                                                       # sound.update(current_time)
#    253
#    254   6302062 1300644496.0    206.4      3.9              is_sound_active = sound.active
#    255   6302062 1413187057.0    224.2      4.2              is_sound_self_call = (
#    256   6932360 1519100848.0    219.1      4.6                  sound.emitter_id == self.id
#    257    630298  167401892.0    265.6      0.5                  and isinstance(sound, DirectSound)
#    258      6462    1620064.0    250.7      0.0                  and not detect_self_call
#    259                                                       )
#    260   6302062 1858376571.0    294.9      5.6              is_sound_reflected_from_self = sound.reflected_from == f"bat_{self.id}"
#    261
#    262                                                       if (
#    263   6302062 1370445022.0    217.5      4.1                  not is_sound_active
#    264   6199942 1339521757.0    216.1      4.0                  or is_sound_self_call
#    265   6196812 1301762966.0    210.1      3.9                  or is_sound_reflected_from_self
#    266                                                       ):
#    267    191018   42912557.0    224.7      0.1                  continue
#    268
#    269                                                       # sound can only be detected if bat is inside the sound wave
#    270   6111044      1.7e+10   2787.4     51.1              if sound.contains_point(self.position):
#    271    200074 1830836532.0   9150.8      5.5                  received_spl = sound.spl_at_receiver(self.position)
#    272
#    273    400148  299741581.0    749.1      0.9                  angle_between_sound_and_bat = sound.direction_vector.angle_between(
#    274    200074   49973802.0    249.8      0.1                      self.position
#    275                                                           )
#    276    400148  351359123.0    878.1      1.1                  hearing_directionality = call_directionality_factor(
#    277    200074   54695797.0    273.4      0.2                      A=self.parameters_df["HEARING_DIRECTIONALITY"][0],
#    278    200074   44931596.0    224.6      0.1                      theta=angle_between_sound_and_bat,
#    279                                                           )
#    280
#    281    200074   58550124.0    292.6      0.2                  received_spl += hearing_directionality
#    282    200074   47914351.0    239.5      0.1                  is_sound_audible = (
#    283    200074   59397674.0    296.9      0.2                      received_spl > self.parameters_df["HEARING_THRESHOLD"][0]
#    284                                                           )
#    285
#    286    200074   48969785.0    244.8      0.1                  if not is_sound_audible:
#    287     35588    8386872.0    235.7      0.0                      continue
#    288    328972  316570369.0    962.3      0.9                  array_of_sound_detections.append(
#    289    164486 1308116967.0   7952.8      3.9                      self.convert_sound_to_dictionary(sound, current_time, received_spl)
#    290                                                           )
#    291     20000   12384022.0    619.2      0.0          return array_of_sound_detections

# %%
# %lprun -f DirectSound.create_echo sim.run()
# Out:
# 0.068
# 0.177
# 0.28
# 0.389
# 0.487
# 0.583
# 0.679
# 0.778
# 0.871
# 0.98
# total_time_taken_to_store_info: 0:00:47.700767
# average_time_per_loop 0:00:00.047701
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.16916 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/sounds.py
# Function: DirectSound.create_echo at line 174
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    174                                               def create_echo(self, point, current_time, normal, reflected_from):
#    175                                                   """Handles EchoSound creation by the sound object.
#    176                                                   Creates an echo at the specified point.
#    177
#    178                                                   Args:
#    179                                                       point (Vector): point of reflection of sound
#    180                                                       current_time (float): time, in seconds, for which the simualtion has been running.
#    181                                                       normal (Vector): Normal vector from the object that the sound reflects from.
#    182                                                       reflected_from (string): The id of the object the sound reflects from.
#    183
#    184                                                   Returns:
#    185                                                       EchoSound: The generated EchoSound object.
#    186                                                   """
#    187      5547    1947933.0    351.2      1.2          if self.has_reflected:
#    188                                                       return None
#    189
#    190     11094   10317210.0    930.0      6.1          angle_between_sound_and_reflection_point = self.direction_vector.angle_between(
#    191      5547    1185002.0    213.6      0.7              point
#    192                                                   )
#    193     11094   11659569.0   1051.0      6.9          call_directionality = call_directionality_factor(
#    194      5547    1678842.0    302.7      1.0              A=self.parameters_df["CALL_DIRECTIONALITY"][0],
#    195      5547    1132619.0    204.2      0.7              theta=angle_between_sound_and_reflection_point,
#    196                                                   )
#    197
#    198      5547    2091753.0    377.1      1.2          object_type = reflected_from[0:4]
#    199      5547    1503133.0    271.0      0.9          if object_type == "wall":
#    200       395     149721.0    379.0      0.1              reflection_loss = self.parameters_df["REFLECTION_LOSS_WALL"][0]
#    201                                                   else:
#    202      5152    1510032.0    293.1      0.9              reflection_loss = self.parameters_df["REFLECTION_LOSS"][0]
#    203
#    204      5547   14040137.0   2531.1      8.3          distance_between_sound_and_echo = self.origin.distance_to(point)
#    205                                                   # print(distance_between_sound_and_echo)
#    206     11094    3877306.0    349.5      2.3          distance_effect_for_echoes = 20 * math.log10(
#    207      5547    1401975.0    252.7      0.8              distance_between_sound_and_echo / 1
#    208                                                   )
#    209      5547    1135150.0    204.6      0.7          spl_corrected_for_width = (
#    210     16641    4575359.0    274.9      2.7              self.initial_spl
#    211      5547    1267005.0    228.4      0.7              - distance_effect_for_echoes
#    212                                                       - (
#    213     11094    3009622.0    271.3      1.8                  self.parameters_df["AIR_ABSORPTION"][0]
#    214      5547    1089196.0    196.4      0.6                  * distance_between_sound_and_echo
#    215                                                       )
#    216                                                   )
#    217
#    218      5547    1810167.0    326.3      1.1          reflected_spl = spl_corrected_for_width - reflection_loss + call_directionality
#    219      5547    1882961.0    339.5      1.1          if reflected_spl < self.parameters_df["HEARING_THRESHOLD"][0]:
#    220                                                       return None
#    221
#    222                                                   # if reflected_spl > spl_corrected_for_width:
#    223                                                   #     print(self.current_spl)
#    224                                                   #     print(
#    225                                                   #         f"reflected spl {reflected_spl}, self spl {self.current_spl}, spl corrected {spl_corrected_for_width}, reflection_loss {reflection_loss}, call directionality {call_directionality}"
#    226                                                   #     )
#    227
#    228     11094   83297987.0   7508.4     49.2          echo = EchoSound(
#    229      5547    1295105.0    233.5      0.8              parameters_df=self.parameters_df,
#    230      5547    1147116.0    206.8      0.7              origin=point,
#    231      5547    1056528.0    190.5      0.6              creation_time=current_time,
#    232      5547    1346378.0    242.7      0.8              emitter_id=self.emitter_id,
#    233      5547    1081227.0    194.9      0.6              initial_spl=reflected_spl,
#    234      5547    1268265.0    228.6      0.7              parent_creation_time=self.creation_time,
#    235      5547    1142840.0    206.0      0.7              reflection_count=1,
#    236      5547    1114814.0    201.0      0.7              reflected_from=reflected_from,
#    237      5547    1063816.0    191.8      0.6              direction_vector=normal,
#    238                                                   )
#    239      5547    4310767.0    777.1      2.5          echo.reflected_obstacles.update(self.reflected_obstacles)
#    240      5547    3770912.0    679.8      2.2          return echo

# %%
# %lprun -f Vector.distance_to sim.run()
# Out:
# 0.014
# 0.071
# 0.166
# 0.263
# 0.354
# 0.461
# 0.565
# 0.67
# 0.763
# 0.868
# 0.974
# total_time_taken_to_store_info: 0:00:23.452646
# average_time_per_loop 0:00:00.023453
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 6.19428 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/vectors.py
# Function: Vector.distance_to at line 54
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     54                                               def distance_to(self, other):
#     55                                                   """measure distance between two vectors
#     56
#     57                                                   Args:
#     58                                                       other (Vector): compute distance to this vector
#     59
#     60                                                   Returns:
#     61                                                       float: distance
#     62                                                   """
#     63   3307440 6194276569.0   1872.8    100.0          return (self - other).magnitude()

# %%
# %lprun -f Bat.update_directon sim.run()
# Out:
# 0.067
# 0.167
# 0.26
# 0.364
# 0.471
# 0.563
# 0.669
# 0.765
# 0.87
# 0.962
# total_time_taken_to_store_info: 0:00:37.323196
# average_time_per_loop 0:00:00.037323
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 16.3697 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py
# Function: Bat.update_directon at line 411
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    411                                               def update_directon(self, current_time, sound_objects):
#    412                                                   """rotate bat according to fix angular speed
#    413
#    414                                                   Args:
#    415                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    416                                                       sound_objects (list): list containing detected sounds
#    417                                                   """
#    418     10000    5517565.0    551.8      0.0          self.time_since_directon_change += self.parameters_df["TIME_STEP"][0]
#    419                                                   # self.reaction_time += self.parameters_df["TIME_STEP"][0]
#    420     30000   10835231.0    361.2      0.1          direction_change_time_interval = self.parameters_df[
#    421     10000    3020197.0    302.0      0.0              "TIME_DELAY_FOR_DIRECTION_CHANGE"
#    422     10000    2571761.0    257.2      0.0          ][0]
#    423     20000   10750659.0    537.5      0.1          self.detections_for_directon_change.extend(
#    424     20000     1.51e+10 756382.1     92.4              self.given_sound_objects_return_sounds_at_bat_position(
#    425     10000    2512866.0    251.3      0.0                  current_time, sound_objects, detect_self_call=False
#    426                                                       )
#    427                                                   )
#    428
#    429                                                   if (
#    430     10000    3559664.0    356.0      0.0              self.time_since_directon_change >= direction_change_time_interval
#    431       101      47090.0    466.2      0.0              and len(self.detections_for_directon_change) != 0
#    432                                                   ):
#    433                                                       # print(len(self.detections_for_directon_change))
#    434       101      29519.0    292.3      0.0              if self.implement_snr:
#    435       202 1057806489.0 5.24e+06      6.5                  heard_sounds = given_sound_objects_return_detected_sounds(
#    436       101      23640.0    234.1      0.0                      self.detections_for_directon_change,
#    437       101      22055.0    218.4      0.0                      direction_change_time_interval,
#    438       101      25608.0    253.5      0.0                      self.hearing_angle_threshold,
#    439       101      29246.0    289.6      0.0                      self.temporal_masking_file,
#    440       101      23824.0    235.9      0.0                      self.min_sound_detection_fraction,
#    441       101      28600.0    283.2      0.0                      self.id,
#    442       101      25547.0    252.9      0.0                      self.include_direct_sounds_in_response,
#    443       101      54138.0    536.0      0.0                      self.parameters_df["CALL_DURATION"][0],
#    444       101      28838.0    285.5      0.0                      self.parameters_df["TIME_STEP"][0],
#    445       101      24512.0    242.7      0.0                      self.rounding_based_on_time_step,
#    446                                                           )
#    447                                                       else:
#    448                                                           heard_sounds = self.detections_for_directon_change
#    449
#    450       101     106015.0   1049.7      0.0              if self.any_consistent_sound == "no":
#    451                                                           self.speed = self.parameters_df["BAT_FAST_SPEED"][0]
#    452                                                           self.call_rate = self.parameters_df["CALL_RATE_FAST"][0]
#    453                                                       else:
#    454       101      82267.0    814.5      0.0                  self.speed = self.parameters_df["BAT_SPEED"][0]
#    455       101      43805.0    433.7      0.0                  self.call_rate = self.parameters_df["CALL_RATE"][0]
#    456
#    457       202   31846315.0 157655.0      0.2              self.next_direction, self.response_type = self.decide_next_direction(
#    458       101      23302.0    230.7      0.0                  heard_sounds
#    459                                                       )
#    460       101    2572934.0  25474.6      0.0              self.detections_for_directon_change = []
#    461       101      83173.0    823.5      0.0              self.time_since_directon_change = -np.inf
#    462                                                       # self.reaction_time = 0
#    463                                                       # self.reaction_state = "responding"
#    464       101     376897.0   3731.7      0.0              if self.next_direction != self.direction.normalize():
#    465       101      40055.0    396.6      0.0                  self.responding_to_direction = (
#    466       101      30653.0    303.5      0.0                      self.next_direction.x,
#    467       101      23025.0    228.0      0.0                      self.next_direction.y,
#    468                                                           )
#    469                                                       else:
#    470                                                           self.responding_to_direction = (np.nan, np.nan)
#    471
#    472       101      37764.0    373.9      0.0              if self.response_type == "attraction":
#    473                                                           self.speed = self.parameters_df["BAT_FAST_SPEED"][0]
#    474                                                   elif (
#    475      9899    2862451.0    289.2      0.0              self.time_since_directon_change >= direction_change_time_interval
#    476                                                       and len(self.detections_for_directon_change) != 0
#    477                                                   ):
#    478                                                       self.ipi_matrix = given_parameters_df_return_grid_matrix_zeros(
#    479                                                           self.parameters_df
#    480                                                       )[0]
#    481                                                       self.memory_window_sum_matrix = self.ipi_matrix.copy()
#    482                                                       # print("oh this part running rrn")
#    483                                                   # if self.reaction_time >= self.parameters_df["REACTION_TIME"][0]:
#    484                                                   #     print("aaa")
#    485                                                   #     self.reaction_state = None
#    486                                                   #     self.reaction_time = -np.inf
#    487     10000    3574792.0    357.5      0.0          rotation_speed = self.parameters_df["BAT_ROTATION_SPEED"][0]
#    488     10000    2482008.0    248.2      0.0          rotation_speed_scaled_by_time_step = (
#    489     10000    3638656.0    363.9      0.0              rotation_speed * self.parameters_df["TIME_STEP"][0]
#    490                                                   )
#    491     20000   94326001.0   4716.3      0.6          self.rotate_towards_given_degree(
#    492     10000    2934867.0    293.5      0.0              self.next_direction, rotation_speed_scaled_by_time_step
#    493                                                   )

# %%
# %lprun -f Bat.given_sound_objects_return_sounds_at_bat_position sim.run()
# Out:
# 0.057
# 0.159
# 0.269
# 0.372
# 0.48
# 0.584
# 0.694
# 0.789
# 0.892
# 0.985
# total_time_taken_to_store_info: 0:01:08.229439
# average_time_per_loop 0:00:00.068229
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 49.163 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py
# Function: Bat.given_sound_objects_return_sounds_at_bat_position at line 237
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    237                                               def given_sound_objects_return_sounds_at_bat_position(
#    238                                                   self, current_time, sound_objects, detect_self_call
#    239                                               ):
#    240                                                   """given sounds generate list of sounds that a bat can hear
#    241
#    242                                                   Args:
#    243                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    244                                                       sound_objects (list): List containing all active sounds in the simulation
#    245                                                       detect_self_call (Bool): If true, add self call to detected, else, skip self call.
#    246
#    247                                                   Returns:
#    248                                                       list: sound detections given time.
#    249                                                   """
#    250     20000    6288049.0    314.4      0.0          array_of_sound_detections = []
#    251   9507294 2274881703.0    239.3      4.6          for sound in sound_objects:
#    252                                                       # sound.update(current_time)
#    253
#    254   9487294 1940815377.0    204.6      3.9              is_sound_active = sound.active
#    255   9487294 2096041041.0    220.9      4.3              is_sound_self_call = (
#    256  10436114 2350260081.0    225.2      4.8                  sound.emitter_id == self.id
#    257    948820  237378180.0    250.2      0.5                  and isinstance(sound, DirectSound)
#    258     16350    4185940.0    256.0      0.0                  and not detect_self_call
#    259                                                       )
#    260   9487294 2992958844.0    315.5      6.1              is_sound_reflected_from_self = sound.reflected_from == f"bat_{self.id}"
#    261
#    262                                                       if (
#    263   9487294 2139981111.0    225.6      4.4                  not is_sound_active
#    264   9377654 1999857024.0    213.3      4.1                  or is_sound_self_call
#    265   9369576 2051351996.0    218.9      4.2                  or is_sound_reflected_from_self
#    266                                                       ):
#    267    260768   58571202.0    224.6      0.1                  continue
#    268
#    269                                                       # sound can only be detected if bat is inside the sound wave
#    270   9226526     2.57e+10   2782.0     52.2              if sound.contains_point(self.position):
#    271    211033 1971464574.0   9342.0      4.0                  received_spl = sound.spl_at_receiver(self.position)
#    272
#    273    422066  300032721.0    710.9      0.6                  angle_between_sound_and_bat = sound.direction_vector.angle_between(
#    274    211033   51723834.0    245.1      0.1                      self.position
#    275                                                           )
#    276    422066  383198681.0    907.9      0.8                  hearing_directionality = call_directionality_factor(
#    277    211033   56694351.0    268.7      0.1                      A=self.parameters_df["HEARING_DIRECTIONALITY"][0],
#    278    211033   46955132.0    222.5      0.1                      theta=angle_between_sound_and_bat,
#    279                                                           )
#    280
#    281    211033   62083975.0    294.2      0.1                  received_spl += hearing_directionality
#    282    211033   49441143.0    234.3      0.1                  is_sound_audible = (
#    283    211033   62293763.0    295.2      0.1                      received_spl > self.parameters_df["HEARING_THRESHOLD"][0]
#    284                                                           )
#    285
#    286    211033   53215889.0    252.2      0.1                  if not is_sound_audible:
#    287     19418    4546493.0    234.1      0.0                      continue
#    288    383230  617087716.0   1610.2      1.3                  array_of_sound_detections.append(
#    289    191615 1670104861.0   8715.9      3.4                      self.convert_sound_to_dictionary(sound, current_time, received_spl)
#    290                                                           )
#    291     20000   13301628.0    665.1      0.0          return array_of_sound_detections

# %%
# %lprun -f given_sound_objects_return_detected_sounds sim.run()
# Out:
# 0.011
# 0.058
# 0.162
# 0.267
# 0.362
# 0.457
# 0.549
# 0.652
# 0.752
# 0.853
# 0.958
# total_time_taken_to_store_info: 0:00:30.601223
# average_time_per_loop 0:00:00.030601
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 1.47369 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/snr_implementation.py
# Function: given_sound_objects_return_detected_sounds at line 498
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    498                                           def given_sound_objects_return_detected_sounds(
#    499                                               sound_objects,
#    500                                               time_threshold_post_call,
#    501                                               angle_threshold,
#    502                                               temporal_masking_df,
#    503                                               minimum_sound_detection_fraction,
#    504                                               focal_bat,
#    505                                               include_direct_sounds,
#    506                                               call_duration,
#    507                                               sim_time_step,
#    508                                               sim_rounding,
#    509                                           ):
#    510                                               """given list of sounds, returns the list of sounds that are detected.
#    511                                               if the sound to masker profile is atleast minimum_sound_detection_fraction
#    512                                               then the sound is considered to be detected.
#    513
#    514                                               Args:
#    515                                                   sound_objects (list): contains all the sound objects exracted from output files
#    516                                                   time_threshold_post_call (float): _description_
#    517                                                   angle_threshold (float): :math:`\\pm` angle in radians of the bat's hearing field
#    518                                                   dir_of_temporal_masking_fn_file (str): directory of temporal masking function file
#    519                                                   minimum_sound_detection_fraction (float): fraction of sound to masker ratio that
#    520                                                                                           needs to be above masking tolerance for detection
#    521                                                   focal_bat (int): id of the bat that is hearing the sounds
#    522                                                   include_direct_sounds (bool): False if direct sounds shouldn't be considered
#    523                                                                               in snr calculations.
#    524
#    525                                               Returns:
#    526                                                   list: contains heard sounds
#    527                                               """
#    528
#    529       214  124980438.0 584020.7      8.5      parsed_sounds = parse_sounds(
#    530       107      71168.0    665.1      0.0          sound_objects,
#    531       107      29832.0    278.8      0.0          time_threshold_post_call,
#    532       107      22595.0    211.2      0.0          angle_threshold,
#    533       107      24719.0    231.0      0.0          focal_bat,
#    534       107      26691.0    249.4      0.0          include_direct_sounds,
#    535       107      26965.0    252.0      0.0          call_duration,
#    536                                               )
#    537       107      59763.0    558.5      0.0      if len(parsed_sounds) == 0:
#    538                                                   return []
#    539       214  174711408.0 816408.4     11.9      parsed_serialized_sounds = filter_sounds_based_on_total_profile(
#    540       107      32422.0    303.0      0.0          parsed_sounds, sim_time_step, sim_rounding
#    541                                               )
#    542       214  154036707.0 719797.7     10.5      parsed_serialized_sounds = serialize_sound_info(
#    543       107      34133.0    319.0      0.0          parsed_serialized_sounds, sim_time_step, sim_rounding
#    544                                               )
#    545                                               # print(len(parsed_serialized_sounds))
#    546       107      63048.0    589.2      0.0      if len(parsed_serialized_sounds) == 0:
#    547                                                   return []
#    548
#    549                                               # print(len(parsed_serialized_sounds))
#    550
#    551       107      35673.0    333.4      0.0      heard_sounds = []
#    552      2173     626660.0    288.4      0.0      for focal_sound in parsed_serialized_sounds:
#    553      4132 1015470284.0 245757.6     68.9          if is_signal_heard(
#    554      2066     481771.0    233.2      0.0              focal_sound,
#    555      2066     439051.0    212.5      0.0              parsed_serialized_sounds,
#    556      2066     427287.0    206.8      0.0              temporal_masking_df,
#    557      2066     421611.0    204.1      0.0              minimum_sound_detection_fraction,
#    558      2066     416319.0    201.5      0.0              sim_time_step,
#    559      2066     460752.0    223.0      0.0              sim_rounding,
#    560                                                   ):
#    561      2066     708114.0    342.7      0.0              heard_sounds.append(focal_sound)
#    562
#    563       107      78820.0    736.6      0.0      return heard_sounds

# %%
# %lprun -f is_signal_heard sim.run()
# Out:
# 0.056
# 0.157
# 0.254
# 0.353
# 0.41
# 0.469
# 0.579
# 0.672
# 0.776
# 0.885
# 0.994
# total_time_taken_to_store_info: 0:00:44.520025
# average_time_per_loop 0:00:00.044520
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.738789 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/snr_implementation.py
# Function: is_signal_heard at line 438
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    438                                           def is_signal_heard(
#    439                                               focal_sound,
#    440                                               parsed_sounds,
#    441                                               temporal_masking_df,
#    442                                               minimum_sound_detection_fraction,
#    443                                               sim_time_step,
#    444                                               sim_rounding,
#    445                                           ):
#    446                                               """given sound and list of potentially masking sound, return if sound is heard or not
#    447                                               if the sound to masker profile is atleast minimum_sound_detection_fraction
#    448                                               then the sound is considered to be detected.
#    449
#    450                                               Args:
#    451                                                   focal_sound (dict): focal sound
#    452                                                   parsed_sounds (list): list of all sounds that can potentially mask
#    453                                                   dir_of_temporal_masking_fn_file (str): directory of temporal masking function file
#    454                                                   minimum_sound_detection_fraction (float): fraction of sound to masker ratio
#    455                                                                                           that needs to be above masking tolerance
#    456                                                                                           for detection
#    457
#    458                                               Returns:
#    459                                                   bool: true if sound is heard, else false
#    460                                               """
#    461                                               # temporal_masking_df = pd.read_csv(dir_of_temporal_masking_fn_file)
#    462      1612     489187.0    303.5      0.1      time_extent_of_temporal_masking_fn_file = [
#    463      1612    9064192.0   5622.9      1.2          np.max(temporal_masking_df["timegap_ms"]),
#    464      1612    7687534.0   4768.9      1.0          np.min(temporal_masking_df["timegap_ms"]),
#    465                                               ]
#    466      3224  522023290.0 161917.9     70.7      focal_sound_masker_ratio, time_axis_given_sound = generate_sound_profile(
#    467      1612     391322.0    242.8      0.1          parsed_sounds,
#    468      1612     408227.0    253.2      0.1          focal_sound,
#    469      1612     374578.0    232.4      0.1          time_extent_of_temporal_masking_fn_file,
#    470      1612     364621.0    226.2      0.0          sim_time_step,
#    471      1612     376297.0    233.4      0.1          sim_rounding,
#    472                                               )
#    473      3224  179856999.0  55786.9     24.3      temporal_masking_thresholds = get_temporal_masking_function_based_on_sound(
#    474      1612     405458.0    251.5      0.1          time_axis_given_sound,
#    475      1612     359308.0    222.9      0.0          temporal_masking_df,
#    476      1612     420183.0    260.7      0.1          focal_sound["duration"],
#    477      1612     398184.0    247.0      0.1          sim_time_step,
#    478                                               )
#    479      1612     435395.0    270.1      0.1      count_total = 0
#    480      1612     366742.0    227.5      0.0      count_focal_sound_greater_masking_threshold = 0
#    481
#    482     14360    3824298.0    266.3      0.5      for i, temporal_masking_threshold in enumerate(temporal_masking_thresholds):
#    483     12748    3827498.0    300.2      0.5          if focal_sound_masker_ratio[i] >= temporal_masking_threshold:
#    484     11524    2678029.0    232.4      0.4              count_focal_sound_greater_masking_threshold += 1
#    485     12748    2846883.0    223.3      0.4          count_total += 1
#    486
#    487      1612     408296.0    253.3      0.1      percent_of_focal_sound_detected = (
#    488      1612     478639.0    296.9      0.1          count_focal_sound_greater_masking_threshold / count_total
#    489                                               )
#    490      1612     436491.0    270.8      0.1      if percent_of_focal_sound_detected >= minimum_sound_detection_fraction:
#    491      1612     867008.0    537.8      0.1          return True
#    492                                               if percent_of_focal_sound_detected < minimum_sound_detection_fraction:
#    493                                                   return False
#    494                                               else:
#    495                                                   raise ValueError("Percent focal sound is messed up!")

# %%
# %lprun -f generate_sound_profile sim.run()
# Out:
# 0.032
# 0.088
# 0.191
# 0.299
# 0.408
# 0.513
# 0.613
# 0.722
# 0.825
# 0.927
# total_time_taken_to_store_info: 0:00:30.913781
# average_time_per_loop 0:00:00.030914
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.668881 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/snr_implementation.py
# Function: generate_sound_profile at line 278
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    278                                           def generate_sound_profile(
#    279                                               list_of_sounds,
#    280                                               focal_sound_object,
#    281                                               time_extent_of_temporal_masking_fn_file,
#    282                                               sim_time_step,
#    283                                               sim_rounding,
#    284                                           ):
#    285                                               """given a focal sound and list of all sounds, generate focal_sound_to_masker_ratio
#    286                                               computes both the focal_sound profile and masker sound profiles.
#    287
#    288
#    289                                               Args:
#    290                                                   list_of_sounds (list): all sounds that can potentially mask the focal sound
#    291                                                   focal_sound_object (dict): focal sound
#    292                                                   time_extent_of_temporal_masking_fn_file (list): first entry is the time before a call to consider
#    293                                                       second entry is the
#    294
#    295                                               Returns:
#    296                                                   list,list: returns the focal sound to masker ratio and
#    297                                                   the time axis centered around focal sound
#    298                                               """
#    299                                               # the - sim_time_step / 2 is cause numpy sometimes includes the last term wtf kms
#    300      1895     600042.0    316.6      0.1      start_time_of_focal_sound = focal_sound_object["time"]
#    301      1895     529338.0    279.3      0.1      ipi_start_time = focal_sound_object["bat_last_call_time"]
#    302
#    303      1895     607891.0    320.8      0.1      duration_before_call_to_consider = start_time_of_focal_sound - ipi_start_time
#    304
#    305                                               # time_extent_of_temporal_masking_fn_file = [0.025, -0.001]
#    306
#    307      3790   13415262.0   3539.6      2.0      start_of_time_axis = np.min(
#    308      1895     535542.0    282.6      0.1          [time_extent_of_temporal_masking_fn_file[0], duration_before_call_to_consider]
#    309                                               )
#    310      1895     477446.0    252.0      0.1      end_of_time_axis = (
#    311      1895     854966.0    451.2      0.1          -focal_sound_object["duration"] + time_extent_of_temporal_masking_fn_file[1]
#    312                                               )
#    313
#    314      1895     488361.0    257.7      0.1      time_extent_of_masking_global_time = [
#    315      1895     575403.0    303.6      0.1          start_time_of_focal_sound - start_of_time_axis,
#    316      1895     552989.0    291.8      0.1          start_time_of_focal_sound - end_of_time_axis,
#    317                                               ]
#    318
#    319      3790    8845999.0   2334.0      1.3      time_axis_given_sound = np.round(
#    320      3790    3405223.0    898.5      0.5          np.arange(
#    321      1895     431817.0    227.9      0.1              start_of_time_axis,
#    322      1895     704504.0    371.8      0.1              end_of_time_axis - sim_time_step / 2,
#    323      1895     479338.0    252.9      0.1              -sim_time_step,
#    324                                                   ),
#    325      1895     476059.0    251.2      0.1          sim_rounding,
#    326                                               )
#    327
#    328      1895    1970003.0   1039.6      0.3      matrix_with_spls = np.zeros(shape=(len(time_axis_given_sound), len(list_of_sounds)))
#    329
#    330     44262   11867932.0    268.1      1.8      for i, sound in enumerate(list_of_sounds):
#    331     42367   10069752.0    237.7      1.5          is_sound_not_focal_sound = (
#    332     42367   41861830.0    988.1      6.3              sound["sound_object_id"] != focal_sound_object["sound_object_id"]
#    333                                                   )
#    334     82839   64845272.0    782.8      9.7          if is_sound_not_focal_sound and sound_within_time_interval(
#    335     40472    9338889.0    230.7      1.4              sound, time_extent_of_masking_global_time
#    336                                                   ):
#    337     64220  145563233.0   2266.6     21.8              time_of_sound_wrt_focal_sound = np.round(
#    338     32110    8883044.0    276.6      1.3                  sound["time"] - focal_sound_object["time"], sim_rounding
#    339                                                       )
#    340
#    341     32110    9147794.0    284.9      1.4              time_intervals_to_add_intensity = (
#    342     32110   30004939.0    934.4      4.5                  sound["occurance_times"] - focal_sound_object["time"]
#    343                                                       )
#    344                                                       # np.arange(
#    345                                                       #     time_of_sound_wrt_focal_sound,
#    346                                                       #     time_of_sound_wrt_focal_sound + sound["duration"] + sim_time_step / 2,
#    347                                                       #     sim_time_step,
#    348                                                       # )
#    349
#    350     80652   40336449.0    500.1      6.0              for j, time_step in enumerate(time_intervals_to_add_intensity):
#    351     48542   71106743.0   1464.8     10.6                  index_to_put_spl = np.where(time_axis_given_sound == time_step)[0]
#    352
#    353     48542   43121904.0    888.3      6.4                  matrix_with_spls[index_to_put_spl, i] = sound["all_spl_values"][j]
#    354
#    355      3790    2698039.0    711.9      0.4      masker_profile = np.array(
#    356      1895  133909408.0  70664.6     20.0          [find_sum_of_db(i, sim_rounding) for i in matrix_with_spls]
#    357                                               )
#    358      1895     529361.0    279.3      0.1      focal_sound_profile = (
#    359      1895    7817951.0   4125.6      1.2          np.ones(shape=(len(time_axis_given_sound))) * focal_sound_object["received_spl"]
#    360                                               )
#    361
#    362      1895    1235683.0    652.1      0.2      focal_sound_masker_ratio = focal_sound_profile - masker_profile
#    363      1895    1592206.0    840.2      0.2      return focal_sound_masker_ratio, time_axis_given_sound

# %%
# %lprun -f generate_sound_profile sim.run()
# Out:
# /home/adityamoger/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/line_profiler/ipython_extension.py:97: UserWarning: Adding a function with a `.__wrapped__` attribute. You may want to profile the wrapped function by adding `generate_sound_profile.__wrapped__` instead.
#   profile = LineProfiler(*funcs)
# 0.003
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('lprun', '-f generate_sound_profile sim.run()')
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/line_profiler/ipython_extension.py:130, in LineProfilerMagics.lprun(self, parameter_s)
#     128 try:
#     129     try:
# --> 130         profile.runctx(arg_str, global_ns, local_ns)
#     131         message = ""
#     132     except SystemExit:
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/line_profiler/profiler_mixin.py:496, in ByCountProfilerMixin.runctx(self, cmd, globals, locals)
#     494 self.enable_by_count()
#     495 try:
# --> 496     exec(cmd, globals, locals)
#     497 finally:
#     498     self.disable_by_count()
#
# File <string>:1
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/simulation_and_plotting/simulation.py:88, in Simulation.run(self)
#      85     sound.update(self.time_elapsed)
#      87 for bat in self.bats:
# ---> 88     bat.update(self.time_elapsed, self.sound_objects)
#      90 self.handle_reflections(self.time_elapsed)
#      92 self.history.append(
#      93     {
#      94         "time": np.round(
#    (...)    131     }
#     132 )
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py:133, in Bat.update(self, current_time, sound_objects)
#     129 # if current_time < 0.5:
#     130 #     print(self.ipi_matrix)
#     131 # print(self.ipi_matrix_timeseries)
#     132 if not self.kill_movement:
# --> 133     self.update_directon(current_time, sound_objects)
#     134     self.cleanup_sounds(current_time)
#     135     self.detect_sounds(current_time, sound_objects)
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py:435, in Bat.update_directon(self, current_time, sound_objects)
#     429 if (
#     430     self.time_since_directon_change >= direction_change_time_interval
#     431     and len(self.detections_for_directon_change) != 0
#     432 ):
#     433     # print(len(self.detections_for_directon_change))
#     434     if self.implement_snr:
# --> 435         heard_sounds = given_sound_objects_return_detected_sounds(
#     436             self.detections_for_directon_change,
#     437             direction_change_time_interval,
#     438             self.hearing_angle_threshold,
#     439             self.temporal_masking_file,
#     440             self.min_sound_detection_fraction,
#     441             self.id,
#     442             self.include_direct_sounds_in_response,
#     443             self.parameters_df["CALL_DURATION"][0],
#     444             self.parameters_df["TIME_STEP"][0],
#     445             self.rounding_based_on_time_step,
#     446         )
#     447     else:
#     448         heard_sounds = self.detections_for_directon_change
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/snr_implementation.py:555, in given_sound_objects_return_detected_sounds(sound_objects, time_threshold_post_call, angle_threshold, temporal_masking_df, minimum_sound_detection_fraction, focal_bat, include_direct_sounds, call_duration, sim_time_step, sim_rounding)
#     553 heard_sounds = []
#     554 for focal_sound in parsed_serialized_sounds:
# --> 555     if is_signal_heard(
#     556         focal_sound,
#     557         parsed_serialized_sounds,
#     558         temporal_masking_df,
#     559         minimum_sound_detection_fraction,
#     560         sim_time_step,
#     561         sim_rounding,
#     562     ):
#     563         heard_sounds.append(focal_sound)
#     565 return heard_sounds
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/snr_implementation.py:468, in is_signal_heard(focal_sound, parsed_sounds, temporal_masking_df, minimum_sound_detection_fraction, sim_time_step, sim_rounding)
#     463 # temporal_masking_df = pd.read_csv(dir_of_temporal_masking_fn_file)
#     464 time_extent_of_temporal_masking_fn_file = [
#     465     np.max(temporal_masking_df["timegap_ms"]),
#     466     np.min(temporal_masking_df["timegap_ms"]),
#     467 ]
# --> 468 focal_sound_masker_ratio, time_axis_given_sound = generate_sound_profile(
#     469     parsed_sounds,
#     470     focal_sound,
#     471     time_extent_of_temporal_masking_fn_file,
#     472     sim_time_step,
#     473     sim_rounding,
#     474 )
#     475 temporal_masking_thresholds = get_temporal_masking_function_based_on_sound(
#     476     time_axis_given_sound,
#     477     temporal_masking_df,
#     478     focal_sound["duration"],
#     479     sim_time_step,
#     480 )
#     481 count_total = 0
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/numba/core/dispatcher.py:424, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     420         msg = (f"{str(e).rstrip()} \n\nThis error may have been caused "
#     421                f"by the following argument(s):\n{args_str}\n")
#     422         e.patch_message(msg)
# --> 424     error_rewrite(e, 'typing')
#     425 except errors.UnsupportedError as e:
#     426     # Something unsupported is present in the user code, add help info
#     427     error_rewrite(e, 'unsupported_error')
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/numba/core/dispatcher.py:365, in _DispatcherBase._compile_for_args.<locals>.error_rewrite(e, issue_type)
#     363     raise e
#     364 else:
# --> 365     raise e.with_traceback(None)
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# Untyped global name 'sound_within_time_interval': Cannot determine Numba type of <class 'function'>
#
# File "dynamic_model/supporting_files/snr_implementation.py", line 336:
# def generate_sound_profile(
#     <source elided>
#         )
#         if is_sound_not_focal_sound and sound_within_time_interval(
#         ^
#
# During: Pass nopython_type_inference
#
# This error may have been caused by the following argument(s):
# - argument 0: Cannot type list element type <class 'dict'>
# - argument 1: Cannot determine Numba type of <class 'dict'>
