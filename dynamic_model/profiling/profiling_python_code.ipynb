# %%
import sys
import numpy as np
import os 
import line_profiler
print(os.getcwd())
os.chdir("/home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/")
sys.path.append("./dynamic_model/")
# sys.path.append("./MISC/exploratory_analysis/")
# sys.path.append("./MISC//")
from simulation.class_simulation import Simulation
from agents.class_sounds import EchoSound, DirectSound
from agents.class_bats import Bat
# from simulation_and_plotting.single_bat_plotter import visualize
from supporting_files.utilities import load_parameters
from supporting_files.snr_implementation import given_sound_objects_return_detected_sounds, is_signal_heard, get_temporal_masking_function_based_on_sound, generate_sound_profile
from supporting_files.vectors import Vector
# %load_ext line_profiler

OUTPUT_DIR = r"./dynamic_model/profiling/dump_files/"
PARAMETER_FILE_DIR = r"./dynamic_model/paramsets/test_group.json"
PARAMETER_DF = load_parameters(PARAMETER_FILE_DIR)
sim = Simulation(PARAMETER_DF, OUTPUT_DIR)
# Out:
# /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/profiling

# %%
OUTPUT_DIR = r"./dynamic_model/profiling/dump_files/"
PARAMETER_FILE_DIR = r"./dynamic_model/paramsets/test_group.json"
PARAMETER_DF = load_parameters(PARAMETER_FILE_DIR)
PARAMETER_DF["SIM_DURATION"]= 5
sim = Simulation(PARAMETER_DF, OUTPUT_DIR)

# %%
# %lprun -f Simulation.run sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:02.797605
# average_time_per_loop 0:00:00.000560
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 2.79132 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/simulation/class_simulation.py
# Function: Simulation.run at line 69
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#     69                                               def run(self):
#     70                                                   """Runs one instance of the simulation.
#     71                                                   After parsing the parameter file, it runs one instance of the simulation
#     72                                                   for those sets of parameters.
#     73                                                   """
#     74         2     226603.0 113301.5      0.0          with open(self.dir_to_store + "bats_initial.pkl", "wb") as f:
# ...

# %%
np.round([1,1,1])
# Out:
# array([1, 1, 1])

# %%
# %lprun -f Simulation.handle_reflections sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:03.108880
# average_time_per_loop 0:00:00.000622
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 2.01316 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/simulation/class_simulation.py
# Function: Simulation.handle_reflections at line 267
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    267                                               def handle_reflections(self, current_time):
#    268                                                   """Generates reflections of the sound objects.
#    269                                                   Soud objects can reflect off of obstacles and bats
#    270                                                   to generate EchoSound s.
#    271
#    272                                                   Args:
# ...

# %%
# %lprun -f Bat.update sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:02.824798
# average_time_per_loop 0:00:00.000565
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.66888 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/class_bats.py
# Function: Bat.update at line 78
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#     78                                               def update(self, current_time, sound_objects, temporal_masking_file):
#     79                                                   """Function to update bats with time.
#     80                                                   This function handles movement update of bat each time step.
#     81                                                   Also takes care of sound emission, detection of active sounds by the bats.
#     82                                                   Bat detections over time is also cleared and stored locally.
#     83
# ...

# %%
# %lprun -f Bat.update_directon sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:02.866079
# average_time_per_loop 0:00:00.000573
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.481489 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/class_bats.py
# Function: Bat.update_directon at line 343
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    343                                               def update_directon(self, current_time, sound_objects, temporal_masking_file):
#    344                                                   """rotate bat according to fix angular speed
#    345
#    346                                                   Args:
#    347                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    348                                                       sound_objects (list): list containing detected sounds
# ...

# %%
# %lprun -f Bat.given_sound_objects_return_sounds_at_bat_position sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:03.038656
# average_time_per_loop 0:00:00.000608
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.362027 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/class_bats.py
# Function: Bat.given_sound_objects_return_sounds_at_bat_position at line 209
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    209                                               def given_sound_objects_return_sounds_at_bat_position(
#    210                                                   self, current_time, sound_objects
#    211                                               ):
#    212                                                   """given sounds generate list of sounds that a bat can hear
#    213
#    214                                                   Args:
# ...

# %%
# %lprun -f EchoSound.contains_point sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:06.828985
# average_time_per_loop 0:00:00.001366
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 4.94024 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/class_sounds.py
# Function: EchoSound.contains_point at line 69
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#     69                                               def contains_point(self, point):
#     70                                                   """Checks whether a given point is within the sound disk.
#     71                                                   This function helps to decide when to generate echoes from objects.
#     72
#     73                                                   Args:
#     74                                                       point (Vector): _description_
#     75
#     76                                                   Returns:
# ...

# %%
# %lprun -f Bat.given_sound_objects_return_sounds_at_bat_position sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:06.695061
# average_time_per_loop 0:00:00.001339
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.756985 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/class_bats.py
# Function: Bat.given_sound_objects_return_sounds_at_bat_position at line 209
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    209                                               def given_sound_objects_return_sounds_at_bat_position(
#    210                                                   self, current_time, sound_objects
#    211                                               ):
#    212                                                   """given sounds generate list of sounds that a bat can hear
#    213
#    214                                                   Args:
# ...

# %%
# %lprun -f DirectSound.create_echo sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:06.786688
# average_time_per_loop 0:00:00.001358
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.150539 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/class_sounds.py
# Function: DirectSound.create_echo at line 163
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    163                                               def create_echo(self, point, current_time, normal, reflected_from):
#    164                                                   """Handles EchoSound creation by the sound object.
#    165                                                   Creates an echo at the specified point.
#    166
#    167                                                   Args:
#    168                                                       point (Vector): point of reflection of sound
# ...

# %%
# %lprun -f Vector.distance_to sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:06.571518
# average_time_per_loop 0:00:00.001315
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 4.54421 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/vectors.py
# Function: Vector.distance_to at line 56
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#     56                                               def distance_to(self, other):
#     57                                                   """measure distance between two vectors
#     58
#     59                                                   Args:
#     60                                                       other (Vector): compute distance to this vector
#     61
#     62                                                   Returns:
#     63                                                       float: distance
#     64                                                   """
# ...

# %%
# %lprun -f Bat.update_directon sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:09.563825
# average_time_per_loop 0:00:00.001913
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.963485 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/class_bats.py
# Function: Bat.update_directon at line 343
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    343                                               def update_directon(self, current_time, sound_objects, temporal_masking_file):
#    344                                                   """rotate bat according to fix angular speed
#    345
#    346                                                   Args:
#    347                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    348                                                       sound_objects (list): list containing detected sounds
# ...

# %%
# %lprun -f Bat.given_sound_objects_return_sounds_at_bat_position sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:09.515934
# average_time_per_loop 0:00:00.001904
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.727443 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/class_bats.py
# Function: Bat.given_sound_objects_return_sounds_at_bat_position at line 209
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    209                                               def given_sound_objects_return_sounds_at_bat_position(
#    210                                                   self, current_time, sound_objects
#    211                                               ):
#    212                                                   """given sounds generate list of sounds that a bat can hear
#    213
#    214                                                   Args:
# ...

# %%
# %lprun -f given_sound_objects_return_detected_sounds sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:09.758897
# average_time_per_loop 0:00:00.001952
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.112567 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/snr_implementation.py
# Function: given_sound_objects_return_detected_sounds at line 426
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    426                                           def given_sound_objects_return_detected_sounds(
#    427                                               sound_objects,
#    428                                               time_threshold_post_call,
#    429                                               angle_threshold,
#    430                                               temporal_masking_df,
#    431                                               minimum_sound_detection_fraction,
#    432                                               focal_bat,
# ...

# %%
# %lprun -f is_signal_heard sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:09.638281
# average_time_per_loop 0:00:00.001928
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.07492 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/snr_implementation.py
# Function: is_signal_heard at line 367
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    367                                           def is_signal_heard(
#    368                                               focal_sound,
#    369                                               parsed_sounds,
#    370                                               temporal_masking_df,
#    371                                               minimum_sound_detection_fraction,
#    372                                               sim_time_step,
#    373                                               sim_rounding,
#    374                                           ):
# ...

# %%
# %lprun -f generate_sound_profile sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:13.144059
# average_time_per_loop 0:00:00.002629
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.031161 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/snr_implementation.py
# Function: generate_sound_profile at line 262
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    262                                           def generate_sound_profile(
#    263                                               list_of_sounds,
#    264                                               focal_sound_object,
#    265                                               time_extent_of_temporal_masking_fn_file,
#    266                                               sim_time_step,
#    267                                               sim_rounding,
#    268                                           ):
# ...

# %%
# %lprun -f generate_sound_profile sim.run()
# Out:
# BLANK_TEST
# total_time_taken_to_store_info: 0:00:13.059011
# average_time_per_loop 0:00:00.002612
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.0231856 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/snr_implementation.py
# Function: generate_sound_profile at line 262
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    262                                           def generate_sound_profile(
#    263                                               list_of_sounds,
#    264                                               focal_sound_object,
#    265                                               time_extent_of_temporal_masking_fn_file,
#    266                                               sim_time_step,
#    267                                               sim_rounding,
#    268                                           ):
# ...
